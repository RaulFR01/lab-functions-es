# %% [markdown]
# # Functions

# %% [markdown]
# En este laboratorio pondremos en práctica algunos de los conceptos que hemos aprendido en los últimos días.
#
# `NOTA: En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando solo la sintaxis más básica de Python y sin funciones como len, count, sum, max, min, in, etc. Dale una oportunidad. 🧑🏻‍💻👩🏻‍💻`
#
# La celda después de cada ejercicio contiene algunas pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
def greater(a,b):
    if a > b:
        return a
    return b
#your code here#tu codigo aquí

# %%
# Para testear tu función
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.090s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más

# %%
#tu codigo aquí
def greatest(lst):
    aux = 0
    for element in lst:
        if element > aux:
            aux = element
    return aux

# %%
# Para testear tu función
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.068s
#
# OK

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_all(lst):
    result = 0
    for element in lst:
        result += element
    return result
#tu codigo aquí

# %%
# Para testear tu función
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.086s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_all(lst):
    result = 1
    for element in lst:
        result *= element
    return result
#tu codigo aquí

# %%
# Para testear tu función
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.090s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def oper_all(arr, oper = "*"):
    if oper == '*':
        return mult_all(arr)
    else:
        return sum_all(arr)
#tu codigo aquí

# %%
# Para testear tu función
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.081s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n-1)
#tu codigo aquí

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.078s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique(lst_un):
#tu codigo aquí

# %%
# Para testear tu función 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.091s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
    dict_={}
    veces=0
    for i in arr:
        if i in dict_:
            dict_[i]+=1
        else:
            dict_[i]=1
    for i in dict_:
        if dict_[i]>veces:
            veces=dict_[i]
            moda=i
        else:
            veces
            moda
    return moda

# %%
# Para testear tu función 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.320s
#
# OK

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
def st_dev(list_sd):
#tu codigo aquí
# Out:
#   Cell In[21], line 2
#     #tu codigo aquí
#                    ^
# SyntaxError: incomplete input

# %%
# Para testear tu función
test_stdev(st_dev)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
def pangram(string):
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(pangram)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
import re
def sort_alpha(string):
    pattern=r'(\w+),'
    orden=sorted(re.findall(pattern, string))
    return orden

# %%
# Para testear tu función 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['idrymbl', 'pmhhe', 'unfkcebbb', 'xxdpady'] != 'idrymbl,myeipz,pmhhe,unfkcebbb,xxdpady' : Should be idrymbl,myeipz,pmhhe,unfkcebbb,xxdpady
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['eiji', 'fkafhqy', 'flccmabxo', 'gqxucec[228 chars]anz'] != 'eiji,fkafhqy,flccmabxo,gqxucectx,guvuyi,[163 chars]janz' : Should be eiji,fkafhqy,flccmabxo,gqxucectx,guvuyi,gwyyd,iasmo,ismmidlmhk,jfspctrhp,jiaij,jpwxu,jxzztqthil,kgxwq,lgolrbibwg,lutujblj,qifuwapev,scaeiplslm,taqrppwxfo,tkbyfg,tlybx,umjnulshb,unkyaoky,ynxvoc,yvxjblp,zijanz
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['ahuybcsqus', 'akgm', 'brpkrkfzj', 'elrf[151 chars]iaf'] != 'ahuybcsqus,akgm,brpkrkfzj,elrfkwb,jloz,j[103 chars]giaf' : Should be ahuybcsqus,akgm,brpkrkfzj,elrfkwb,jloz,jzkbh,lvkcvgir,miomxgjrr,njzmczqdn,nusamfeznr,orqqd,scks,sluohm,ughortip,uzdlmby,vkgsyv,wztxcgzpu,wzzy,xgiaf
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['anedkrvws', 'bfug', 'cnstppfi', 'deaifp[103 chars]zlw'] != 'anedkrvws,bfug,cnstppfi,deaifppbwd,drhz,[72 chars]zzlw' : Should be anedkrvws,bfug,cnstppfi,deaifppbwd,drhz,jiraiq,mxswej,ooywmum,qhbjpmxai,qiiab,qsutpsemg,ukujwud,uodsyfktj,whbet,zzlw
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['birxslw', 'blbssgycik', 'dlydj', 'ewanz[132 chars]gvp'] != 'birxslw,blbssgycik,dlydj,ewanzl,eycbwpao[93 chars]ugvp' : Should be birxslw,blbssgycik,dlydj,ewanzl,eycbwpao,gdgsbjlv,gmszzv,hiqwewicmd,hqypxjkctf,llqyogw,nega,orgmuozx,plxbkdgqra,pxjlynm,qtzywoi,xsfbcugvp
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['bsmbemj', 'pwbhs', 'qwpjqupfb'] != 'bsmbemj,ihaatcwa,pwbhs,qwpjqupfb' : Should be bsmbemj,ihaatcwa,pwbhs,qwpjqupfb
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['

#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['bbexzevste', 'emzpkee', 'heccwvyazw', '[71 chars]hqv'] != 'bbexzevste,emzpkee,heccwvyazw,mewnx,mpbg[52 chars]phqv' : Should be bbexzevste,emzpkee,heccwvyazw,mewnx,mpbgmb,ngmkzao,osfy,qvdghbjgwo,sokmaanplh,tzkfvfwwm,ycmsphqv
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['hkmjszeqre', 'owfmrfsxmk', 'qnrnrqyo', 'qszhu', 'uzqrotvhmt'] != 'hkmjszeqre,owfmrfsxmk,qnrnrqyo,qszhu,uxlqist,uzqrotvhmt' : Should be hkmjszeqre,owfmrfsxmk,qnrnrqyo,qszhu,uxlqist,uzqrotvhmt
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['bhpjnwdnu', 'bhsrfa', 'fudhpxf', 'gohzq[119 chars]csc'] != 'bhpjnwdnu,bhsrfa,fudhpxf,gohzqjziz,ioaeb[81 chars]tcsc' : Should be bhpjnwdnu,bhsrfa,fudhpxf,gohzqjziz,ioaebe,jyecydhj,kaeuso,krct,nbnrlq,nkhzvfahu,prmo,pykc,qjjwq,sial,wqfulvnhq,znfoy,zrtctcsc
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['ifffepjbjh', 'knuivdnhjo', 'ngrxfdvfgx', 'sqlxzjrioc', 'tbhkkkgkj'] != 'ifffepjbjh,knuivdnhjo,ngrxfdvfgx,qzunch,sqlxzjrioc,tbhkkkgkj' : Should be ifffepjbjh,knuivdnhjo,ngrxfdvfgx,qzunch,sqlxzjrioc,tbhkkkgkj
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['agkkxy', 'araqweqa', 'bklxb', 'cwqkpqv'[229 chars]nlr'] != 'agkkxy,araqweqa,bklxb,cwqkpqv,egxbztj,ff[168 chars]snlr' : Should be agkkxy,araqweqa,bklxb,cwqkpqv,egxbztj,ffqqxcbus,hhkahigbba,hwmki,jinkjkva,khprhekhhz,mhlkyodlu,nhiybw,ombbpam,pdcjfcqb,qaliwankfa,qsdujfzvmo,qwqrpvjjp,rwbyhumlxl,rxnudxxvll,vfanbxfnhh,vovphrnii,ybtnpw,zbkq,zksnlr
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['ehbbnwl', 'hnyzqncrw', 'inyybqkqb', 'jr[181 chars]igs'] != 'ehbbnwl,hnyzqncrw,inyybqkqb,jrequuvobn,j[132 chars]ligs' : Should be ehbbnwl,hnyzqncrw,inyybqkqb,jrequuvobn,jwdqeumwev,jzidgmofu,kgitdlqqz,kmyeugvwq,lcjktezwwv,ldqj,maebgqdyr,msofac,oynuekq,pfgz,pkyeoz,pnlkvqmcjg,tovgpewjdz,upxq,vbww,veowr,zligs
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/root/jupyter/lab-functions-es/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['apegodyl', 'aprkespt', 'cbgkg', 'dlpoii[114 chars]wrg'] != 'apegodyl,aprkespt,cbgkg,dlpoii,fdpm,khqw[81 chars]fvfk' : Should be apegodyl,aprkespt,cbgkg,dlpoii,fdpm,khqwmzz,mlvuyssn,ogiqpko,pgitajnaf,phdenfeii,pqtkvi,psdgs,rrlcrv,txoign,velwrg,ylchggfvfk
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.339s
#
# FAILED (failures=100)

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es.

# %%
def check_pass(password):
#tu codigo aquí

# %%
# Para testear tu función
test_pass(check_pass)
